# %%
import torch
from ultralytics import YOLO
import cv2

# %%
model = YOLO(r"C:\Users\iTech\Desktop\vision_task_shelves_count\yolov8m-onnex4\content\runs\detect\yolov8m-onnex4\weights\best.pt")
# Load an image using OpenCV

# %%
img=cv2.imread(r"C:\Users\iTech\Desktop\vision_task_shelves_count\yolov8m-onnex4\content\runs\detect\yolov8m-onnex4\confusion_matrix.png")

# %%
model.predict(img)
# Out:
# 0: 480x640 (no detections), 571.8ms
# Speed: 20.1ms preprocess, 571.8ms inference, 18.4ms postprocess per image at shape (1, 3, 480, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'empty', 1: 'product'}
#  obb: None
#  orig_img: array([[[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[255, 255, 255],
#          [255, 255, 255],
# ...

# %%
onnx_model_path = r"..\model.onnx"
model.export(format='onnx')
# Out:
# Ultralytics YOLOv8.1.20 🚀 Python-3.9.18 torch-2.2.1+cpu CPU (Intel Core(TM) i7-8850H 2.60GHz)
#
# PyTorch: starting from 'C:\Users\iTech\Desktop\vision_task_shelves_count\yolov8m-onnex4\content\runs\detect\yolov8m-onnex4\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 6, 8400) (49.6 MB)
#
# ONNX: starting export with onnx 1.15.0 opset 17...
# ONNX: export success ✅ 2.5s, saved as 'C:\Users\iTech\Desktop\vision_task_shelves_count\yolov8m-onnex4\content\runs\detect\yolov8m-onnex4\weights\best.onnx' (98.8 MB)
#
# Export complete (5.0s)
# Results saved to C:\Users\iTech\Desktop\vision_task_shelves_count\yolov8m-onnex4\content\runs\detect\yolov8m-onnex4\weights
# Predict:         yolo predict task=detect model=C:\Users\iTech\Desktop\vision_task_shelves_count\yolov8m-onnex4\content\runs\detect\yolov8m-onnex4\weights\best.onnx imgsz=640
# ...

# %%
# pip install tensorflow-io
# Out:
# ...
#    ---------------------------------------- 0.0/22.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/22.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/22.9 MB 660.6 kB/s eta 0:00:35
#    ---------------------------------------- 0.1/22.9 MB 1.1 MB/s eta 0:00:21
#    ---------------------------------------- 0.2/22.9 MB 1.4 MB/s eta 0:00:17
#     --------------------------------------- 0.3/22.9 MB 1.7 MB/s eta 0:00:14
#     --------------------------------------- 0.4/22.9 MB 1.8 MB/s eta 0:00:13
#     --------------------------------------- 0.6/22.9 MB 1.9 MB/s eta 0:00:12
#    - -------------------------------------- 0.7/22.9 MB 2.0 MB/s eta 0:00:12
#    - -------------------------------------- 0.8/22.9 MB 1.9 MB/s eta 0:00:12
#    - -------------------------------------- 0.9/22.9 MB 2.1 MB/s eta 0:00:11
#    - -------------------------------------- 1.0/22.9 MB 2.1 MB/s eta 0:00:11
# ...

# %%
import tensorflow as tf
import tensorflow_io as tfio

# Specify the path to your ONNX model file
onnx_model_path = r"C:\Users\iTech\Desktop\vision_task_shelves_count\yolov8m-onnex4\content\runs\detect\yolov8m-onnex4\weights\best.onnx"

# Read the ONNX model file as a binary string
onnx_model_string = tf.io.read_file(onnx_model_path)

# Decode the ONNX model binary string into a TensorFlow graph
onnx_model = tfio.experimental.tensorflow_onnx.decode_onnx(onnx_model_string)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 11
#       8 onnx_model_string = tf.io.read_file(onnx_model_path)
#      10 # Decode the ONNX model binary string into a TensorFlow graph
# ---> 11 onnx_model = tfio.experimental.tensorflow_onnx.decode_onnx(onnx_model_string)
#
# AttributeError: module 'tensorflow_io.python.api.experimental' has no attribute 'tensorflow_onnx'

# %%
# Assuming input_data is your input data in the appropriate format
input_data = ... 

# Perform inference using the ONNX model
output = onnx_model(input_data)

# Process the output as needed
