# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="zpKL4bCDXu2EBhbMACi8")
project = rf.workspace("bongwon-park-moipa").project("restpark67")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.2 MB/s eta 0:00:00
# ...
# WARNING: The candidate selected for download or install is a yanked version: 'opencv-python-headless' candidate (version 4.8.0.74 at https://files.pythonhosted.org/packages/76/02/f128517f3ade4bb5f71e2afd8461dba70e3f466ce745fa1fd1fade9ad1b7/opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (from https://pypi.org/simple/opencv-python-headless/) (requires-python:>=3.6))
# Reason for being yanked: deprecated, use 4.8.0.76
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import cv2
from IPython.display import display , Image

# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 782.8/782.8 kB 6.5 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
# !yolo train model=yolov8n.pt data=/content/restpark67-1/data.yaml epochs=200 imgsz=640 batch=-1 patience=20 cache=True
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 78.5MB/s]
# Ultralytics YOLOv8.2.35 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo train model=yolov8m.pt data=/content/restpark67-1/data.yaml epochs=300 imgsz=640 batch=-1  cache=True plots=True patience=50 name='yolov8m'
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 239MB/s]
# Ultralytics YOLOv8.2.35 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo train model=yolov8m.pt data=/content/restpark67-1/data.yaml epochs=300 imgsz=640 batch=-1  cache=True plots=True patience=50 name='yolov8m-onnex' profile=True format='onnx'
# Out:
# Ultralytics YOLOv8.2.35 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo train model=yolov8m.pt data=/content/restpark67-1/data.yaml epochs=300 imgsz=640 batch=-1 cache=True plots=True name='yolov8m-onnex5' profile=True format='onnx'
# Out:
# Ultralytics YOLOv8.2.35 🚀 Python-3.10.12 torch-2.3.0+cu121
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 591, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py", line 655, in train
#     self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/trainer.py", line 101, in __init__
#     self.device = select_device(self.args.device, self.args.batch)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/utils/torch_utils.py", line 136, in select_device
#     raise ValueError(
# ...

# %%
# !yolo predict model=/content/runs/detect/yolov8m-onnex4/weights/best.pt source='/content/restpark67-1/test/images/IMG_5758-orig_mp4-9_jpg.rf.91342565503db2e67768335c7918ce47.jpg' save=True save_txt=True save_conf=True
# Out:
# Ultralytics YOLOv8.2.35 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840918 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/1 /content/restpark67-1/test/images/IMG_5758-orig_mp4-9_jpg.rf.91342565503db2e67768335c7918ce47.jpg: 640x640 14 emptys, 55 products, 37.1ms
# Speed: 3.1ms preprocess, 37.1ms inference, 676.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2
# 1 label saved to runs/detect/predict2/labels
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from google.colab import files

# Example: Download a single file
files.download('/content/runs')

# # Example: Download multiple files (create a zip file)
# !zip -r files.zip /path/to/your/folder/
# files.download('files.zip')
